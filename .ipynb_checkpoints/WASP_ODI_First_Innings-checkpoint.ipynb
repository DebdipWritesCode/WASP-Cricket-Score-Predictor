# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./Cricket Dataset.csv")
# Out:
# C:\Users\debdi\AppData\Local\Temp\ipykernel_29928\3141108476.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./Cricket Dataset.csv")

# %%
df.head(15)
# Out:
#     Balls  MatchNo Innings BattingTeam    City      Date Match_Type  \
# 0       1        1       1   Australia  London  9/4/2009        ODI
# 1       2        1       1   Australia  London  9/4/2009        ODI
# 2       3        1       1   Australia  London  9/4/2009        ODI
# 3       4        1       1   Australia  London  9/4/2009        ODI
# 4       5        1       1   Australia  London  9/4/2009        ODI
# 5       6        1       1   Australia  London  9/4/2009        ODI
# 6       7        1       1   Australia  London  9/4/2009        ODI
# 7       8        1       1   Australia  London  9/4/2009        ODI
# 8       9        1       1   Australia  London  9/4/2009        ODI
# 9      10        1       1   Australia  London  9/4/2009        ODI
# 10     11        1       1   Australia  London  9/4/2009        ODI
# 11     12        1       1   Australia  London  9/4/2009        ODI
# 12     13        1       1   Australia  London  9/4/2009        ODI
# 13     14        1       1   Australia  London  9/4/2009        ODI
# 14     15        1       1   Australia  London  9/4/2009        ODI
#
#    Toss_Decision Toss_Winner            Venue  ... Temp Score Wickets  \
# 0          field     England  Kennington Oval  ...    1     1       0
# 1          field     England  Kennington Oval  ...    1     1       0
# 2          field     England  Kennington Oval  ...    1     1       0
# 3          field     England  Kennington Oval  ...    1     1       0
# 4          field     England  Kennington Oval  ...    1     5       0
# 5          field     England  Kennington Oval  ...    1     5       0
# 6          field     England  Kennington Oval  ...    1     5       0
# 7          field     England  Kennington Oval  ...    1     5       0
# 8          field     England  Kennington Oval  ...    1     5       0
# 9          field     England  Kennington Oval  ...    1     5       0
# 10         field     England  Kennington Oval  ...    1     5       0
# 11         field     England  Kennington Oval  ...    1     5       0
# 12         field     England  Kennington Oval  ...    1     5       0
# 13         field     England  Kennington Oval  ...    1     5       0
# 14         field     England  Kennington Oval  ...    1     5       0
#
#     Wicket_ball Ext_bl fsdasfasd Ball_b  Wicket_kind  Wicket_Fielders  \
# 0             0      1         0      1          NaN              NaN
# 1             0      1         1      1          NaN              NaN
# 2             0      1         2      2          NaN              NaN
# 3             0      1         3      3          NaN              NaN
# 4             0      1         4      4          NaN              NaN
# 5             0      1         5      5          NaN              NaN
# 6             0      1         6      6          NaN              NaN
# 7             0      1         7      7          NaN              NaN
# 8             0      1         8      8          NaN              NaN
# 9             0      1         9      9          NaN              NaN
# 10            0      1        10     10          NaN              NaN
# 11            0      1        11     11          NaN              NaN
# 12            0      1        12     12          NaN              NaN
# 13            0      1        13     13          NaN              NaN
# 14            0      1        14     14          NaN              NaN
#
#     Player_out
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
#
# [15 rows x 33 columns]

# %%
selected_columns = df.columns[[1,2,13,22,24,25,26,29]]
selected_columns
# Out:
# Index(['MatchNo', 'Innings', 'Over', 'Runs_Total', 'Score', 'Wickets',
#        'Wicket_ball', 'Ball_b'],
#       dtype='object')

# %% [markdown]
# ### Description of Selected Columns
#
# - **MatchNo**: The unique number assigned to the match.
# - **Innings**: Indicates whether the data corresponds to the 1st or 2nd innings (values: 1 or 2).
# - **Over**: Represents the current over in the match, formatted as `x.y` (e.g., `0.1`, `0.5`, `3.6`), where `x` is the over count and `y` is the ball number within the over.
# - **Runs_Total**: The total runs scored on that particular ball, including extras.
# - **Score**: The cumulative score of the batting team at that point in the match.
# - **Wickets**: The total number of wickets lost by the batting team so far.
# - **Wicket_ball**: A binary field (`0` or `1`) indicating whether the given ball resulted in a wicket (`1` if a wicket fell, `0` otherwise).
# - **Ball_b**: The sequential ball number in the match (e.g., in an ODI, it will be at least 300 or more if there are extra deliveries due to no-balls or wides).

# %%
data = df[selected_columns]
data = data[data["Innings"] == 1]

# %%
data.head()
# Out:
#    MatchNo Innings  Over  Runs_Total  Score  Wickets  Wicket_ball  Ball_b
# 0        1       1   0.1           1      1        0            0       1
# 1        1       1   0.2           0      1        0            0       1
# 2        1       1   0.3           0      1        0            0       2
# 3        1       1   0.4           0      1        0            0       3
# 4        1       1   0.5           4      5        0            0       4

# %% [markdown]
# ### Calculating R(b, w) which represents the average runs scored at a specific ball number b and a given number of wickets lost w.

# %%
sum_run = np.zeros((300, 11))
count = np.zeros((300, 11))
runbw = np.zeros((300, 11))

for i, row in data.iterrows():
    balls = int(row["Ball_b"]) 
    wickets = int(row["Wickets"])  
    runs = int(row["Runs_Total"])  

    if 1 <= balls <= 300 and 0 <= wickets <= 10:
        sum_run[balls - 1, wickets] += runs  
        count[balls - 1, wickets] += 1  

for i in range(0, 300):
    for j in range(0, 11):
        if count[i, j] > 0:
            runbw[i, j] = sum_run[i, j] / count[i, j]

# %% [markdown]
# ### Calculating P(b, w)
